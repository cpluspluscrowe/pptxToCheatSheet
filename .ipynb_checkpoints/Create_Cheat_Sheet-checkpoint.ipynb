# %%
# %config IPCompleter.greedy=True
from pptx import Presentation
import operator
from pprint import pprint

prs = Presentation("./ch16.pptx")

paragraphs = {}


class Paragraph():
    def __init__(self, level,paragraph_count, text, isBold, block_count):
        self.block_count = block_count
        self.paragraph_count = paragraph_count
        self.level = level
        self.text = text
        self.isBold = isBold
        self.context = None
        self.entities = None
    def getColoredText(self):
        text = []
        for word in self.text.split():
            if word.lower() in self.entities:
                text .append('''<a style="color:red;">''' + word + "</a>")
            else:
                text.append(word)
        return " ".join(text)
    def __str__(self):
        html = "<div>"
        content = "&emsp;"*(self.block_count) + "&#8226;" + self.getColoredText()
        if self.block_count == 0:
            html += "<b>" + content + "</b>"
        else:
            html +=  "</tab>" + content 
        html += str(self.context) + "</div>"
        return html
    def setWordsToHighlight(self,entities):
        if type(entities) == str:
            entities = entities.split()
        self.entities = entities

slides = []
d = {}
slide_count = 0
for ppSlide in prs.slides:
    d[slide_count] = {}
    shape_count = 0
    for shape in ppSlide.shapes:
        if not shape.has_text_frame:
            continue
        else:
            d[slide_count][shape_count] = []
            paragraph_count = 0
            for block in shape.text_frame.paragraphs:
                paragraph = Paragraph(block.level, 
                                      paragraph_count, block.text, block.font.bold, shape_count)
                if block.text == "Chapter 16 Component-based software engineering" or block.text == "19/11/2014" or block.text.isnumeric() or block.text.isspace() or block.text == "":
                    break
                d[slide_count][shape_count].append(paragraph)
                paragraph_count += 1
            shape_count += 1
    slide_count += 1

# %%
#sort title blocks
paragraphs = {}
for a in d:
    for b in d[a]:
        for c in d[a][b]:
            if c.block_count == 0:
                paragraphs[c.text] = c

# associated a number with each title block
context_cnt = 0
for title_block in sorted(paragraphs):
    paragraphs[title_block].context = context_cnt
    context_cnt += 1

# assign a number to each paragraph, denoting its title block #
for a in d:
    for b in sorted(d[a]):
        for c in d[a][b]:
            if c.block_count == 0:
                context_count = c.context
            if c.block_count > 0:
                c.context = context_count

# %%
general_data = {}
# sort general data
general_count = 0
for a in d:
    for b in sorted(d[a]):
        for c in d[a][b]:
            if c.block_count == 0:
                points = []
            if c.block_count > 0:
                points.append(c)
    general_data[general_count] = points
    general_count += 1

# %%
import math
from textblob import TextBlob as tb

def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)

# %%
output = '''
CBSE
Component-based
effective reuse
stand-alone
Independent components 
Middleware
inter-operability
reuse
interfere
well-defined
interfaces
infrastructures
inter-operate
competing
Enterprise
Beans
hindered
communicating
executable entity
published
Heinmann
Composable
Deployable
Documented
Independent
Standardized
parameterized
component
deployability
independence
remote
RPC
URL
EJB
Usage
Deployment
container
generalizing
service
processes
acquisition
developed
external
certification
specification
generaldomain
abstraction
fundamental
trade-off
application-specific
broaden
adaptation
Integrate
rewriting
legacy
enhancement
certification
integrate
ideal
outline
Trust
Requirements
Validation
Navigation
assembling
glue code
Sequential
Hierarchical
Additive
incompatibilities
Parameter
Operation
incompatibility
incompleteness
documentation
Constraint
OCL
library
catalogue
functional
non-functional
emergent
reuse-based
interleaved
wiring
Distributed
Client–server 
Architectural
service
Virtually
distributed
confined
enterprise
resource
openness
concurrency
scalability
fault tolerance
complex
arises
top-down control
security
policies
failure
management
practice
achieve
transparency
logically
open
accepted
programming
web service
open standards
reflects
cope
manage a system
distinction
scaling-up
scaling-out
system instances
attack
incompatible
interception
interruption
modification
fabrication
QoS
threshold
degraded
service
critical
inevitable
procedural
Message-based
sending
remote procedure calls
middleware
callee
parses
sender
receiver
communicate
provision
interaction
internet
remote
external
presentation
data handling
processing
database
multi-tier
client-server
master-slave
architecture
peer-to-peer
real-time
master
computation
aquisition
sensors
two-tier
fat-client
thin-client
legacy
disadvantages
network
javascript
mobile
auto-updates
blurred
p2p
decentralised
semi-centralised
computationally-intensive
stored
managed
security
SaaS
service
configurability
tenancy
multi-tenancy


'''.lower()
#cheat sheet top
html = '''
<head>
<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bulma/0.6.2/css/bulma.min.css">
<style>
body {
    column-count:4;
    margin:1px;
    column-gap: 40px;
}
div {
    font-size:80%;
}
.group {
    margin:3px;
    border:1px solid black;
}
</style>
</head>
<body>
'''



for paragraph in sorted(general_data):
    html += '''<div class="group">'''
    for point in general_data[paragraph]:
        point.setWordsToHighlight(output)
        print(str(point))
        print()
        html += str(point)
    html += '''</div>'''
html += '</body>'

with open("cheat_sheet.html","w") as f:
    f.write(html)
# Out:
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> and <a style="color:red;">component</a> models50</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">CBSE</a> <a style="color:red;">processes</a>50</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> composition50</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component-based</a> software engineering (CBSE) is an approach to software development that relies on the <a style="color:red;">reuse</a> of entities called ‘software components’.26</div>
#
# <div></tab>&emsp;&#8226;It emerged from the <a style="color:red;">failure</a> of object-oriented development to support <a style="color:red;">effective</a> reuse. Single object classes are too detailed and specific.26</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> are more abstract than object classes and can be considered to be <a style="color:red;">stand-alone</a> <a style="color:red;">service</a> providers. They can exist as <a style="color:red;">stand-alone</a> entities.26</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Independent</a> <a style="color:red;">components</a> specified by their interfaces.6</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> <a style="color:red;">standards</a> to facilitate <a style="color:red;">component</a> integration.6</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Middleware</a> that provides support for <a style="color:red;">component</a> inter-operability.6</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> development process that is geared to reuse.6</div>
#
# <div></tab>&emsp;&#8226;Apart from the benefits of reuse, <a style="color:red;">CBSE</a> is based on sound software engineering design principles:5</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> are <a style="color:red;">independent</a> so do not <a style="color:red;">interfere</a> with each other;5</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> implementations are hidden;5</div>
#
# <div></tab>&emsp;&#8226;Communication is through <a style="color:red;">well-defined</a> interfaces;5</div>
#
# <div></tab>&emsp;&#8226;One <a style="color:red;">components</a> can be replaced by another if its interface is maintained;5</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> <a style="color:red;">infrastructures</a> offer <a style="color:red;">a</a> range of standard services.5</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Standards</a> need to be established so that <a style="color:red;">components</a> can <a style="color:red;">communicate</a> with each other and inter-operate.24</div>
#
# <div></tab>&emsp;&#8226;Unfortunately, several <a style="color:red;">competing</a> <a style="color:red;">component</a> <a style="color:red;">standards</a> were established:24</div>
#
# <div></tab>&emsp;&#8226;Sun’s <a style="color:red;">Enterprise</a> Java <a style="color:red;">Beans</a>24</div>
#
# <div></tab>&emsp;&#8226;Microsoft’s COM and .NET24</div>
#
# <div></tab>&emsp;&#8226;CORBA’s CCM24</div>
#
# <div></tab>&emsp;&#8226;In practice, these multiple <a style="color:red;">standards</a> have <a style="color:red;">hindered</a> the uptake of CBSE. It is impossible for <a style="color:red;">components</a> <a style="color:red;">developed</a> using different approaches to work together.24</div>
#
# <div></tab>&emsp;&#8226;An <a style="color:red;">executable</a> <a style="color:red;">service</a> is <a style="color:red;">a</a> type of <a style="color:red;">independent</a> component. It has <a style="color:red;">a</a> ‘provides’ interface but not <a style="color:red;">a</a> ‘requires’ interface.45</div>
#
# <div></tab>&emsp;&#8226;From the outset, services have been based around <a style="color:red;">standards</a> so there are no problems in <a style="color:red;">communicating</a> between services offered by different vendors.45</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">System</a> performance may be slower with services but this approach is replacing <a style="color:red;">CBSE</a> in many systems.45</div>
#
# <div></tab>&emsp;&#8226;Covered in Chapter 1845</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> provide <a style="color:red;">a</a> <a style="color:red;">service</a> without regard to where the <a style="color:red;">component</a> is executing or its <a style="color:red;">programming</a> language27</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> <a style="color:red;">component</a> is an <a style="color:red;">independent</a> <a style="color:red;">executable</a> <a style="color:red;">entity</a> that can be made up of one or more <a style="color:red;">executable</a> objects;27</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">component</a> interface is <a style="color:red;">published</a> and all interactions are through the <a style="color:red;">published</a> interface;27</div>
#
# <div></tab>&emsp;&#8226;Councill and Heinmann:17</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> software <a style="color:red;">component</a> is <a style="color:red;">a</a> software element that conforms to <a style="color:red;">a</a> <a style="color:red;">component</a> model and can be independently deployed and composed without <a style="color:red;">modification</a> according to <a style="color:red;">a</a> composition standard.17</div>
#
# <div></tab>&emsp;&#8226;Szyperski:17</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> software <a style="color:red;">component</a> is <a style="color:red;">a</a> unit of composition with contractually specified <a style="color:red;">interfaces</a> and explicit context dependencies only. <a style="color:red;">A</a> software <a style="color:red;">component</a> can be deployed independently and is subject to composition by third-parties.17</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Composable</a>15</div>
#
# <div></tab>&emsp;&#8226;For <a style="color:red;">a</a> <a style="color:red;">component</a> to be composable, all <a style="color:red;">external</a> interactions must take place through publicly defined interfaces. In addition, it must provide <a style="color:red;">external</a> access to information about itself, such as its methods and attributes.15</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Deployable</a>15</div>
#
# <div></tab>&emsp;&#8226;To be deployable, <a style="color:red;">a</a> <a style="color:red;">component</a> has to be self-contained. It must be able to operate as <a style="color:red;">a</a> <a style="color:red;">stand-alone</a> <a style="color:red;">entity</a> on <a style="color:red;">a</a> <a style="color:red;">component</a> platform that provides an implementation of the <a style="color:red;">component</a> model. This usually means that the <a style="color:red;">component</a> is binary and does not have to be compiled before it is deployed. If <a style="color:red;">a</a> <a style="color:red;">component</a> is implemented as <a style="color:red;">a</a> service, it does not have to be deployed by <a style="color:red;">a</a> user of <a style="color:red;">a</a> component. Rather, it is deployed by the <a style="color:red;">service</a> provider.15</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Documented</a>15</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> have to be fully <a style="color:red;">documented</a> so that potential users can decide whether or not the <a style="color:red;">components</a> meet their needs. The syntax and, ideally, the semantics of all <a style="color:red;">component</a> <a style="color:red;">interfaces</a> should be specified.15</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Independent</a>15</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> <a style="color:red;">component</a> should be independent—it should be possible to compose and deploy it without having to use other specific components. In situations where the <a style="color:red;">component</a> needs externally provided services, these should be explicitly set out in <a style="color:red;">a</a> ‘requires’ interface specification.15</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Standardized</a>15</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> standardization means that <a style="color:red;">a</a> <a style="color:red;">component</a> used in <a style="color:red;">a</a> <a style="color:red;">CBSE</a> process has to conform to <a style="color:red;">a</a> standard <a style="color:red;">component</a> model. This model may define <a style="color:red;">component</a> interfaces, <a style="color:red;">component</a> metadata, documentation, composition, and deployment.15</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">component</a> is an independent, <a style="color:red;">executable</a> entity. It does not have to be compiled before it is used with other components.14</div>
#
# <div></tab>&emsp;&#8226;The services offered by <a style="color:red;">a</a> <a style="color:red;">component</a> are made available through an interface and all <a style="color:red;">component</a> interactions take place through that interface.14</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">component</a> interface is expressed in terms of <a style="color:red;">parameterized</a> operations and its internal state is never exposed.14</div>
#
# <div></tab>&emsp;&#8226;Provides interface20</div>
#
# <div></tab>&emsp;&#8226;Defines the services that are provided by the <a style="color:red;">component</a> to other components.20</div>
#
# <div></tab>&emsp;&#8226;This interface, essentially, is the <a style="color:red;">component</a> API. It defines the methods that can be called by <a style="color:red;">a</a> user of the component.20</div>
#
# <div></tab>&emsp;&#8226;Requires interface20</div>
#
# <div></tab>&emsp;&#8226;Defines the services that specifies what services must be made available for the <a style="color:red;">component</a> to execute as specified.20</div>
#
# <div></tab>&emsp;&#8226;This does not compromise the <a style="color:red;">independence</a> or <a style="color:red;">deployability</a> of <a style="color:red;">a</a> <a style="color:red;">component</a> because the ‘requires’ interface does not define how these services should be provided.20</div>
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;Note UML notation. Ball and sockets can fit together.21</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> are accessed using <a style="color:red;">remote</a> <a style="color:red;">procedure</a> <a style="color:red;">calls</a> (RPCs).13</div>
#
# <div></tab>&emsp;&#8226;Each <a style="color:red;">component</a> has <a style="color:red;">a</a> unique identifier (usually <a style="color:red;">a</a> URL) and can be referenced from any networked computer.13</div>
#
# <div></tab>&emsp;&#8226;Therefore it can be called in <a style="color:red;">a</a> similar way as <a style="color:red;">a</a> <a style="color:red;">procedure</a> or method running on <a style="color:red;">a</a> local computer.13</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> <a style="color:red;">component</a> model is <a style="color:red;">a</a> definition of <a style="color:red;">standards</a> for <a style="color:red;">component</a> implementation, <a style="color:red;">documentation</a> and deployment.23</div>
#
# <div></tab>&emsp;&#8226;Examples of <a style="color:red;">component</a> models23</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">EJB</a> model (Enterprise Java Beans)23</div>
#
# <div></tab>&emsp;&#8226;COM+ model (.NET model)23</div>
#
# <div></tab>&emsp;&#8226;Corba <a style="color:red;">Component</a> Model23</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">component</a> model specifies how <a style="color:red;">interfaces</a> should be defined and the elements that should be included in an interface definition.23</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Interfaces</a>32</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> are defined by specifying their interfaces. The <a style="color:red;">component</a> model specifies how the <a style="color:red;">interfaces</a> should be defined and the elements, such as <a style="color:red;">operation</a> names, parameters and exceptions, which should be included in the interface definition.32</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Usage</a>32</div>
#
# <div></tab>&emsp;&#8226;In order for <a style="color:red;">components</a> to be <a style="color:red;">distributed</a> and accessed remotely, they need to have <a style="color:red;">a</a> unique name or handle associated with them. This has to be globally unique.32</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Deployment</a>32</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">component</a> model includes <a style="color:red;">a</a> <a style="color:red;">specification</a> of how <a style="color:red;">components</a> should be packaged for <a style="color:red;">deployment</a> as independent, <a style="color:red;">executable</a> entities.32</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> models are the basis for <a style="color:red;">middleware</a> that provides support for executing components.40</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> model implementations provide:40</div>
#
# <div></tab>&emsp;&#8226;Platform services that allow <a style="color:red;">components</a> written according to the model to communicate;40</div>
#
# <div></tab>&emsp;&#8226;Support services that are application-independent services used by different components.40</div>
#
# <div></tab>&emsp;&#8226;To use services provided by <a style="color:red;">a</a> model, <a style="color:red;">components</a> are deployed in <a style="color:red;">a</a> container. This is <a style="color:red;">a</a> set of <a style="color:red;">interfaces</a> used to access the <a style="color:red;">service</a> implementations.40</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">CBSE</a> <a style="color:red;">processes</a> are software <a style="color:red;">processes</a> that support <a style="color:red;">component-based</a> software engineering.8</div>
#
# <div></tab>&emsp;&#8226;They take into account the possibilities of <a style="color:red;">reuse</a> and the different process activities involved in developing and using reusable components.8</div>
#
# <div></tab>&emsp;&#8226;Development for <a style="color:red;">reuse</a>8</div>
#
# <div></tab>&emsp;&#8226;This process is concerned with developing <a style="color:red;">components</a> or services that will be reused in other applications. It usually involves <a style="color:red;">generalizing</a> existing components.8</div>
#
# <div></tab>&emsp;&#8226;Development with <a style="color:red;">reuse</a>8</div>
#
# <div></tab>&emsp;&#8226;This process is the process of developing new applications using existing <a style="color:red;">components</a> and services.8</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> <a style="color:red;">acquisition</a> is the process of acquiring <a style="color:red;">components</a> for <a style="color:red;">reuse</a> or development into <a style="color:red;">a</a> reusable component.46</div>
#
# <div></tab>&emsp;&#8226;It may involve accessing locally- <a style="color:red;">developed</a> <a style="color:red;">components</a> or services or finding these <a style="color:red;">components</a> from an <a style="color:red;">external</a> source.46</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> <a style="color:red;">management</a> is concerned with managing <a style="color:red;">a</a> company’s reusable components, ensuring that they are properly catalogued, <a style="color:red;">stored</a> and made available for reuse.46</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> <a style="color:red;">certification</a> is the process of checking <a style="color:red;">a</a> <a style="color:red;">component</a> and certifying that it meets its specification.46</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">CBSE</a> for <a style="color:red;">reuse</a> focuses on <a style="color:red;">component</a> development.7</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> <a style="color:red;">developed</a> for <a style="color:red;">a</a> specific application usually have to be generalised to make them reusable.7</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> <a style="color:red;">component</a> is most likely to be reusable if it associated with <a style="color:red;">a</a> stable domain <a style="color:red;">abstraction</a> (business object).7</div>
#
# <div></tab>&emsp;&#8226;For example, in <a style="color:red;">a</a> hospital stable domain abstractions are associated with the <a style="color:red;">fundamental</a> purpose - nurses, patients, treatments, etc.7</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> for <a style="color:red;">reuse</a> may be specially constructed by generalising existing components.18</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> reusability18</div>
#
# <div></tab>&emsp;&#8226;Should reflect stable domain abstractions;18</div>
#
# <div></tab>&emsp;&#8226;Should hide state representation;18</div>
#
# <div></tab>&emsp;&#8226;Should be as <a style="color:red;">independent</a> as possible;18</div>
#
# <div></tab>&emsp;&#8226;Should publish exceptions through the <a style="color:red;">component</a> interface.18</div>
#
# <div></tab>&emsp;&#8226;There is <a style="color:red;">a</a> <a style="color:red;">trade-off</a> between reusability and usability18</div>
#
# <div></tab>&emsp;&#8226;The more general the interface, the greater the reusability but it is then more <a style="color:red;">complex</a> and hence less usable.18</div>
#
# <div></tab>&emsp;&#8226;Remove <a style="color:red;">application-specific</a> methods.12</div>
#
# <div></tab>&emsp;&#8226;Change names to make them general.12</div>
#
# <div></tab>&emsp;&#8226;Add methods to <a style="color:red;">broaden</a> coverage.12</div>
#
# <div></tab>&emsp;&#8226;Make exception <a style="color:red;">handling</a> consistent.12</div>
#
# <div></tab>&emsp;&#8226;Add <a style="color:red;">a</a> configuration interface for <a style="color:red;">component</a> adaptation.12</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Integrate</a> required <a style="color:red;">components</a> to reduce dependencies.12</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> should not handle exceptions themselves, because each application will have its own <a style="color:red;">requirements</a> for exception handling.33</div>
#
# <div></tab>&emsp;&#8226;Rather, the <a style="color:red;">component</a> should define what exceptions can arise and should publish these as part of the interface.33</div>
#
# <div></tab>&emsp;&#8226;In practice, however, there are two problems with this:33</div>
#
# <div></tab>&emsp;&#8226;Publishing all exceptions leads to bloated <a style="color:red;">interfaces</a> that are harder to understand. This may put off potential users of the component.33</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">operation</a> of the <a style="color:red;">component</a> may depend on local exception handling, and changing this may have serious implications for the functionality of the component.33</div>
#
# <div></tab>&emsp;&#8226;Existing <a style="color:red;">legacy</a> systems that fulfil <a style="color:red;">a</a> useful business function can be re-packaged as <a style="color:red;">components</a> for reuse.38</div>
#
# <div></tab>&emsp;&#8226;This involves writing <a style="color:red;">a</a> wrapper <a style="color:red;">component</a> that implements provides and requires <a style="color:red;">interfaces</a> then accesses the <a style="color:red;">legacy</a> system.38</div>
#
# <div></tab>&emsp;&#8226;Although costly, this can be much less expensive than <a style="color:red;">rewriting</a> the <a style="color:red;">legacy</a> system.38</div>
#
# <div></tab>&emsp;&#8226;The development cost of reusable <a style="color:red;">components</a> may be higher than the cost of specific equivalents. This extra reusability <a style="color:red;">enhancement</a> cost should be an organization rather than <a style="color:red;">a</a> project cost.44</div>
#
# <div></tab>&emsp;&#8226;Generic <a style="color:red;">components</a> may be less space-efficient and may have longer execution times than their specific equivalents.44</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> <a style="color:red;">management</a> involves deciding how to classify the <a style="color:red;">component</a> so that it can be discovered, making the <a style="color:red;">component</a> available either in <a style="color:red;">a</a> repository or as <a style="color:red;">a</a> service, maintaining information about the use of the <a style="color:red;">component</a> and keeping track of different <a style="color:red;">component</a> versions.22</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> company with <a style="color:red;">a</a> <a style="color:red;">reuse</a> program may carry out some form of <a style="color:red;">component</a> <a style="color:red;">certification</a> before the <a style="color:red;">component</a> is made available for reuse.22</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Certification</a> means that someone apart from the developer checks the quality of the component.22</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">CBSE</a> with <a style="color:red;">reuse</a> process has to find and <a style="color:red;">integrate</a> reusable components.10</div>
#
# <div></tab>&emsp;&#8226;When reusing components, it is essential to make trade-offs between <a style="color:red;">ideal</a> <a style="color:red;">requirements</a> and the services actually provided by available components.10</div>
#
# <div></tab>&emsp;&#8226;This involves:10</div>
#
# <div></tab>&emsp;&#8226;Developing <a style="color:red;">outline</a> requirements;10</div>
#
# <div></tab>&emsp;&#8226;Searching for <a style="color:red;">components</a> then modifying <a style="color:red;">requirements</a> according to available functionality.10</div>
#
# <div></tab>&emsp;&#8226;Searching again to find if there are better <a style="color:red;">components</a> that meet the revised requirements.10</div>
#
# <div></tab>&emsp;&#8226;Composing <a style="color:red;">components</a> to create the system.10</div>
#
# <div></tab>&emsp;&#8226;Trust. You need to be able to <a style="color:red;">trust</a> the supplier of <a style="color:red;">a</a> component. At best, an untrusted <a style="color:red;">component</a> may not operate as advertised; at worst, it can breach your security.19</div>
#
# <div></tab>&emsp;&#8226;Requirements. Different groups of <a style="color:red;">components</a> will satisfy different requirements.19</div>
#
# <div></tab>&emsp;&#8226;Validation.19</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">component</a> <a style="color:red;">specification</a> may not be detailed enough to allow comprehensive tests to be developed.19</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> may have unwanted functionality. How can you test this will not <a style="color:red;">interfere</a> with your application?19</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> <a style="color:red;">validation</a> involves developing <a style="color:red;">a</a> set of test cases for <a style="color:red;">a</a> <a style="color:red;">component</a> (or, possibly, extending test cases supplied with that component) and developing <a style="color:red;">a</a> test harness to run <a style="color:red;">component</a> tests.25</div>
#
# <div></tab>&emsp;&#8226;The major problem with <a style="color:red;">component</a> <a style="color:red;">validation</a> is that the <a style="color:red;">component</a> <a style="color:red;">specification</a> may not be sufficiently detailed to allow you to develop <a style="color:red;">a</a> complete set of <a style="color:red;">component</a> tests.25</div>
#
# <div></tab>&emsp;&#8226;As well as testing that <a style="color:red;">a</a> <a style="color:red;">component</a> for <a style="color:red;">reuse</a> does what you require, you may also have to check that the <a style="color:red;">component</a> does not include any malicious <a style="color:red;">code</a> or functionality that you don’t need.25</div>
#
# <div></tab>&emsp;&#8226;In 1996, the 1st test flight of the Ariane 5 rocket ended in disaster when the launcher went out of <a style="color:red;">control</a> 37 seconds after take off.3</div>
#
# <div></tab>&emsp;&#8226;The problem was due to <a style="color:red;">a</a> reused <a style="color:red;">component</a> from <a style="color:red;">a</a> previous version of the launcher (the Inertial <a style="color:red;">Navigation</a> System) that failed because assumptions made when that <a style="color:red;">component</a> was <a style="color:red;">developed</a> did not hold for Ariane 5.3</div>
#
# <div></tab>&emsp;&#8226;The functionality that failed in this <a style="color:red;">component</a> was not required in Ariane 5.3</div>
#
# <div></tab>&emsp;&#8226;The process of <a style="color:red;">assembling</a> <a style="color:red;">components</a> to create <a style="color:red;">a</a> system.16</div>
#
# <div></tab>&emsp;&#8226;Composition involves integrating <a style="color:red;">components</a> with each other and with the <a style="color:red;">component</a> infrastructure.16</div>
#
# <div></tab>&emsp;&#8226;Normally you have to write ‘glue code’ to <a style="color:red;">integrate</a> components.16</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Sequential</a> composition (1) where the composed <a style="color:red;">components</a> are executed in sequence. This involves composing the provides <a style="color:red;">interfaces</a> of each component.52</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Hierarchical</a> composition (2) where one <a style="color:red;">component</a> <a style="color:red;">calls</a> on the services of another. The provides interface of one <a style="color:red;">component</a> is composed with the requires interface of another.52</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Additive</a> composition (3) where the <a style="color:red;">interfaces</a> of two <a style="color:red;">components</a> are put together to create <a style="color:red;">a</a> new component. Provides and requires <a style="color:red;">interfaces</a> of integrated <a style="color:red;">component</a> is <a style="color:red;">a</a> combination of <a style="color:red;">interfaces</a> of constituent components.52</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Code</a> that allows <a style="color:red;">components</a> to work together34</div>
#
# <div></tab>&emsp;&#8226;If <a style="color:red;">A</a> and B are composed sequentially, then <a style="color:red;">glue</a> <a style="color:red;">code</a> has to call A, collect its results then call B using these results, transforming them into the format required by B.34</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Glue</a> <a style="color:red;">code</a> may be used to resolve interface incompatibilities.34</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Parameter</a> <a style="color:red;">incompatibility</a> where operations have the same name but are of different types.35</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Operation</a> <a style="color:red;">incompatibility</a> where the names of operations in the composed <a style="color:red;">interfaces</a> are different.35</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Operation</a> <a style="color:red;">incompleteness</a> where the provides interface of one <a style="color:red;">component</a> is <a style="color:red;">a</a> subset of the requires interface of another.35</div>
#
# <div></tab>&emsp;&#8226;Address the problem of <a style="color:red;">component</a> <a style="color:red;">incompatibility</a> by reconciling the <a style="color:red;">interfaces</a> of the <a style="color:red;">components</a> that are composed.1</div>
#
# <div></tab>&emsp;&#8226;Different types of adaptor are required depending on the type of composition.1</div>
#
# <div></tab>&emsp;&#8226;An addressFinder and <a style="color:red;">a</a> mapper <a style="color:red;">component</a> may be composed through an adaptor that strips the postal <a style="color:red;">code</a> from an address and passes this to the mapper component.1</div>
#
# <div></tab>&emsp;&#8226;Composition through an adaptor1</div>
#
# <div></tab>&emsp;&emsp;&#8226;The <a style="color:red;">component</a> postCodeStripper is the adaptor that facilitates the <a style="color:red;">sequential</a> composition of addressFinder and mapper components.1</div>
#
# <div></tab>&emsp;&#8226;Address the problem of <a style="color:red;">component</a> <a style="color:red;">incompatibility</a> by reconciling the <a style="color:red;">interfaces</a> of the <a style="color:red;">components</a> that are composed.1</div>
#
# <div></tab>&emsp;&#8226;Different types of adaptor are required depending on the type of composition.1</div>
#
# <div></tab>&emsp;&#8226;An addressFinder and <a style="color:red;">a</a> mapper <a style="color:red;">component</a> may be composed through an adaptor that strips the postal <a style="color:red;">code</a> from an address and passes this to the mapper component.1</div>
#
# <div></tab>&emsp;&#8226;Composition through an adaptor1</div>
#
# <div></tab>&emsp;&emsp;&#8226;The <a style="color:red;">component</a> postCodeStripper is the adaptor that facilitates the <a style="color:red;">sequential</a> composition of addressFinder and mapper components.1</div>
#
# <div></tab>&emsp;&#8226;You have to rely on <a style="color:red;">component</a> <a style="color:red;">documentation</a> to decide if <a style="color:red;">interfaces</a> that are syntactically compatible are actually compatible.36</div>
#
# <div></tab>&emsp;&#8226;Consider an interface for <a style="color:red;">a</a> PhotoLibrary component:36</div>
#
# <div></tab>&emsp;&emsp;&emsp;&emsp;&#8226;“This method adds <a style="color:red;">a</a> photograph to the <a style="color:red;">library</a> and associates the photograph identifier and <a style="color:red;">catalogue</a> descriptor with the photograph.”41</div>
#
# <div></tab>&emsp;&#8226;The Object <a style="color:red;">Constraint</a> Language (OCL) has been designed to define constraints that are associated with UML models.48</div>
#
# <div></tab>&emsp;&#8226;It is based around the notion of pre and post condition <a style="color:red;">specification</a> – common to many formal methods.48</div>
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;-- The context keyword names the <a style="color:red;">component</a> to which the conditions apply47</div>
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;context addItem47</div>
#
# <div></tab>&emsp;&#8226;As specified, the <a style="color:red;">OCL</a> associated with the Photo <a style="color:red;">Library</a> <a style="color:red;">component</a> states that:43</div>
#
# <div></tab>&emsp;&#8226;There must not be <a style="color:red;">a</a> photograph in the <a style="color:red;">library</a> with the same identifier as the photograph to be entered;43</div>
#
# <div></tab>&emsp;&#8226;The <a style="color:red;">library</a> must exist - assume that creating <a style="color:red;">a</a> <a style="color:red;">library</a> adds <a style="color:red;">a</a> single item to it;43</div>
#
# <div></tab>&emsp;&#8226;Each new entry increases the size of the <a style="color:red;">library</a> by 1;43</div>
#
# <div></tab>&emsp;&#8226;If you retrieve using the same identifier then you get back the photo that you added;43</div>
#
# <div></tab>&emsp;&#8226;If you look up the <a style="color:red;">catalogue</a> using that identifier, then you get back the <a style="color:red;">catalogue</a> entry that you made.43</div>
#
# <div></tab>&emsp;&#8226;When composing components, you may find conflicts between <a style="color:red;">functional</a> and <a style="color:red;">non-functional</a> requirements, and conflicts between the need for rapid delivery and <a style="color:red;">system</a> evolution.30</div>
#
# <div></tab>&emsp;&#8226;You need to make decisions such as:30</div>
#
# <div></tab>&emsp;&#8226;What composition of <a style="color:red;">components</a> is <a style="color:red;">effective</a> for delivering the <a style="color:red;">functional</a> requirements?30</div>
#
# <div></tab>&emsp;&#8226;What composition of <a style="color:red;">components</a> allows for future change?30</div>
#
# <div></tab>&emsp;&#8226;What will be the <a style="color:red;">emergent</a> properties of the composed system?30</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">CBSE</a> is <a style="color:red;">a</a> <a style="color:red;">reuse-based</a> approach to defining and implementing loosely coupled <a style="color:red;">components</a> into systems.None</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> <a style="color:red;">component</a> is <a style="color:red;">a</a> software unit whose functionality and dependencies are completely defined by its interfaces.None</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Components</a> may be implemented as <a style="color:red;">executable</a> elements included in <a style="color:red;">a</a> <a style="color:red;">system</a> or as <a style="color:red;">external</a> services.None</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">A</a> <a style="color:red;">component</a> model defines <a style="color:red;">a</a> set of <a style="color:red;">standards</a> that <a style="color:red;">component</a> providers and composers should follow.None</div>
#
# <div></tab>&emsp;&#8226;The key <a style="color:red;">CBSE</a> <a style="color:red;">processes</a> are <a style="color:red;">CBSE</a> for <a style="color:red;">reuse</a> and <a style="color:red;">CBSE</a> with reuse.None</div>
#
# <div></tab>&emsp;&#8226;During the <a style="color:red;">CBSE</a> process, the <a style="color:red;">processes</a> of <a style="color:red;">requirements</a> engineering and <a style="color:red;">system</a> design are interleaved.37</div>
#
# <div></tab>&emsp;&#8226;<a style="color:red;">Component</a> composition is the process of ‘wiring’ <a style="color:red;">components</a> together to create <a style="color:red;">a</a> system.37</div>
#
# <div></tab>&emsp;&#8226;When composing reusable components, you normally have to write adaptors to reconcile different <a style="color:red;">component</a> interfaces.37</div>
#
# <div></tab>&emsp;&#8226;When choosing compositions, you have to consider required functionality, <a style="color:red;">non-functional</a> <a style="color:red;">requirements</a> and <a style="color:red;">system</a> evolution.37</div>

# %%
print(str(point))
# Out:
# <div></tab>&emsp;&#8226;When choosing compositions, you have to consider required functionality, <a style="color:red;">non-functional</a> <a style="color:red;">requirements</a> and <a style="color:red;">system</a> evolution.37</div>
