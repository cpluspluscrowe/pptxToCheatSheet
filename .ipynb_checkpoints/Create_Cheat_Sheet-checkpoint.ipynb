# %%
# %config IPCompleter.greedy=True
from pptx import Presentation
import operator
from pprint import pprint

prs = Presentation("./ch16.pptx")

paragraphs = {}


class Paragraph():
    def __init__(self, level,paragraph_count, text, isBold, block_count):
        self.block_count = block_count
        self.paragraph_count = paragraph_count
        self.level = level
        self.text = text
        self.isBold = isBold
        self.context = None
    def __str__(self):
        html = "<div>"
        content = "&emsp;"*(self.block_count) + "&#8226;" + self.text
        if self.block_count == 0:
            html += "<b>" + content + "</b>"
        else:
            html +=  "</tab>" + content 
        html += str(self.context) + "</div>"
        return html

slides = []
d = {}
slide_count = 0
for ppSlide in prs.slides:
    d[slide_count] = {}
    shape_count = 0
    for shape in ppSlide.shapes:
        if not shape.has_text_frame:
            continue
        else:
            d[slide_count][shape_count] = []
            paragraph_count = 0
            for block in shape.text_frame.paragraphs:
                paragraph = Paragraph(block.level, 
                                      paragraph_count, block.text, block.font.bold, shape_count)
                if block.text == "Chapter 16 Component-based software engineering" or block.text == "19/11/2014" or block.text.isnumeric() or block.text.isspace() or block.text == "":
                    break
                d[slide_count][shape_count].append(paragraph)
                paragraph_count += 1
            shape_count += 1
    slide_count += 1

# %%
#sort title blocks
paragraphs = {}
for a in d:
    for b in d[a]:
        for c in d[a][b]:
            if c.block_count == 0:
                paragraphs[c.text] = c

# associated a number with each title block
context_cnt = 0
for title_block in sorted(paragraphs):
    paragraphs[title_block].context = context_cnt
    context_cnt += 1

# assign a number to each paragraph, denoting its title block #
for a in d:
    for b in sorted(d[a]):
        for c in d[a][b]:
            if c.block_count == 0:
                context_count = c.context
            if c.block_count > 0:
                c.context = context_count

# %%
#cheat sheet top
html = '''
<head>
<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bulma/0.6.2/css/bulma.min.css">
<style>
div {
    font-size:80%;
}
.group {
    margin:3px;
    max-width:30%;
    float:left;
    border:1px solid black;
}
</style>
</head>
'''

# %%
general_data = {}
# sort general data
general_count = 0
for a in d:
    for b in sorted(d[a]):
        for c in d[a][b]:
            if c.block_count == 0:
                points = []
            if c.block_count > 0:
                points.append(c)
        general_data[general_count] = points
        general_count += 1

# %%
for paragraph in sorted(general_data):
    html += '''<div class="group">'''
    for point in general_data[paragraph]:
        html += str(point)
    html += '''</div>'''

with open("cheat_sheet.html","w") as f:
    f.write(html)

# %%
import math
from textblob import TextBlob as tb

def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)


from nltk.tokenize import sent_tokenize, word_tokenize
#words = word_tokenize(example)
data = tb(example)

with open("9thEditionText.txt","r") as f:
    book = f.read()

most_important_words = []

bloblist = [data]
for i, blob in enumerate(bloblist):
    print("Top words in document {}".format(i + 1))
    scores = {word: tfidf(word, blob, bloblist) for word in blob.words}
    sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    for word, score in sorted_words[:3]:
        most_important_words.append(word)
        print(word, round(score, 5))
# Out:
# Top words in document 1
# During -0.04951
# CBSE -0.04951
# process -0.04951

# %%
for paragraph in sorted(general_data):
    for point in general_data[paragraph]:
        print(point)
        print(printEntities(point.text))
        print()
# Out:
# <div></tab>&emsp;&#8226;Components and component models 50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;CBSE processes50</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components and component models 50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;CBSE processes50</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components and component models 50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;CBSE processes50</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components and component models 50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;CBSE processes50</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components and component models 50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;CBSE processes50</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition50</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component-based software engineering (CBSE) is an approach to software development that relies on the reuse of entities called ‘software components’.26</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;It emerged from the failure of object-oriented development to support effective reuse. Single object classes are too detailed and specific.26</div>
# {'Single'}
# None
#
# <div></tab>&emsp;&#8226;Components are more abstract than object classes and can be considered to be stand-alone service providers. They can exist as stand-alone entities.26</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component-based software engineering (CBSE) is an approach to software development that relies on the reuse of entities called ‘software components’.26</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;It emerged from the failure of object-oriented development to support effective reuse. Single object classes are too detailed and specific.26</div>
# {'Single'}
# None
#
# <div></tab>&emsp;&#8226;Components are more abstract than object classes and can be considered to be stand-alone service providers. They can exist as stand-alone entities.26</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component-based software engineering (CBSE) is an approach to software development that relies on the reuse of entities called ‘software components’.26</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;It emerged from the failure of object-oriented development to support effective reuse. Single object classes are too detailed and specific.26</div>
# {'Single'}
# None
#
# <div></tab>&emsp;&#8226;Components are more abstract than object classes and can be considered to be stand-alone service providers. They can exist as stand-alone entities.26</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component-based software engineering (CBSE) is an approach to software development that relies on the reuse of entities called ‘software components’.26</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;It emerged from the failure of object-oriented development to support effective reuse. Single object classes are too detailed and specific.26</div>
# {'Single'}
# None
#
# <div></tab>&emsp;&#8226;Components are more abstract than object classes and can be considered to be stand-alone service providers. They can exist as stand-alone entities.26</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component-based software engineering (CBSE) is an approach to software development that relies on the reuse of entities called ‘software components’.26</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;It emerged from the failure of object-oriented development to support effective reuse. Single object classes are too detailed and specific.26</div>
# {'Single'}
# None
#
# <div></tab>&emsp;&#8226;Components are more abstract than object classes and can be considered to be stand-alone service providers. They can exist as stand-alone entities.26</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent components specified by their interfaces.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standards to facilitate component integration.6</div>
# {'Component'}
# None
#
# <div></tab>&emsp;&#8226;Middleware that provides support for component inter-operability.6</div>
# {'Middleware'}
# None
#
# <div></tab>&emsp;&#8226;A development process that is geared to reuse.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent components specified by their interfaces.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standards to facilitate component integration.6</div>
# {'Component'}
# None
#
# <div></tab>&emsp;&#8226;Middleware that provides support for component inter-operability.6</div>
# {'Middleware'}
# None
#
# <div></tab>&emsp;&#8226;A development process that is geared to reuse.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent components specified by their interfaces.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standards to facilitate component integration.6</div>
# {'Component'}
# None
#
# <div></tab>&emsp;&#8226;Middleware that provides support for component inter-operability.6</div>
# {'Middleware'}
# None
#
# <div></tab>&emsp;&#8226;A development process that is geared to reuse.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent components specified by their interfaces.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standards to facilitate component integration.6</div>
# {'Component'}
# None
#
# <div></tab>&emsp;&#8226;Middleware that provides support for component inter-operability.6</div>
# {'Middleware'}
# None
#
# <div></tab>&emsp;&#8226;A development process that is geared to reuse.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent components specified by their interfaces.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standards to facilitate component integration.6</div>
# {'Component'}
# None
#
# <div></tab>&emsp;&#8226;Middleware that provides support for component inter-operability.6</div>
# {'Middleware'}
# None
#
# <div></tab>&emsp;&#8226;A development process that is geared to reuse.6</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Apart from the benefits of reuse, CBSE is based on sound software engineering design principles:5</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Components are independent so do not interfere with each other;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component implementations are hidden;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Communication is through well-defined interfaces;5</div>
# {'Communication'}
# None
#
# <div></tab>&emsp;&#8226;One components can be replaced by another if its interface is maintained;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component infrastructures offer a range of standard services.5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Apart from the benefits of reuse, CBSE is based on sound software engineering design principles:5</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Components are independent so do not interfere with each other;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component implementations are hidden;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Communication is through well-defined interfaces;5</div>
# {'Communication'}
# None
#
# <div></tab>&emsp;&#8226;One components can be replaced by another if its interface is maintained;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component infrastructures offer a range of standard services.5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Apart from the benefits of reuse, CBSE is based on sound software engineering design principles:5</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Components are independent so do not interfere with each other;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component implementations are hidden;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Communication is through well-defined interfaces;5</div>
# {'Communication'}
# None
#
# <div></tab>&emsp;&#8226;One components can be replaced by another if its interface is maintained;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component infrastructures offer a range of standard services.5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Apart from the benefits of reuse, CBSE is based on sound software engineering design principles:5</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Components are independent so do not interfere with each other;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component implementations are hidden;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Communication is through well-defined interfaces;5</div>
# {'Communication'}
# None
#
# <div></tab>&emsp;&#8226;One components can be replaced by another if its interface is maintained;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component infrastructures offer a range of standard services.5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Apart from the benefits of reuse, CBSE is based on sound software engineering design principles:5</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Components are independent so do not interfere with each other;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component implementations are hidden;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Communication is through well-defined interfaces;5</div>
# {'Communication'}
# None
#
# <div></tab>&emsp;&#8226;One components can be replaced by another if its interface is maintained;5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component infrastructures offer a range of standard services.5</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Standards need to be established so that components can communicate with each other and inter-operate.24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Unfortunately, several competing component standards were established:24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Sun’s Enterprise Java Beans24</div>
# {'Enterprise Java Beans', 'Sun'}
# None
#
# <div></tab>&emsp;&#8226;Microsoft’s COM and .NET24</div>
# {'COM', 'Microsoft'}
# None
#
# <div></tab>&emsp;&#8226;CORBA’s CCM24</div>
# {'CORBA', 'CCM'}
# None
#
# <div></tab>&emsp;&#8226;In practice, these multiple standards have hindered the uptake of CBSE. It is impossible for components developed using different approaches to work together. 24</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Standards need to be established so that components can communicate with each other and inter-operate.24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Unfortunately, several competing component standards were established:24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Sun’s Enterprise Java Beans24</div>
# {'Enterprise Java Beans', 'Sun'}
# None
#
# <div></tab>&emsp;&#8226;Microsoft’s COM and .NET24</div>
# {'COM', 'Microsoft'}
# None
#
# <div></tab>&emsp;&#8226;CORBA’s CCM24</div>
# {'CORBA', 'CCM'}
# None
#
# <div></tab>&emsp;&#8226;In practice, these multiple standards have hindered the uptake of CBSE. It is impossible for components developed using different approaches to work together. 24</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Standards need to be established so that components can communicate with each other and inter-operate.24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Unfortunately, several competing component standards were established:24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Sun’s Enterprise Java Beans24</div>
# {'Enterprise Java Beans', 'Sun'}
# None
#
# <div></tab>&emsp;&#8226;Microsoft’s COM and .NET24</div>
# {'COM', 'Microsoft'}
# None
#
# <div></tab>&emsp;&#8226;CORBA’s CCM24</div>
# {'CORBA', 'CCM'}
# None
#
# <div></tab>&emsp;&#8226;In practice, these multiple standards have hindered the uptake of CBSE. It is impossible for components developed using different approaches to work together. 24</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Standards need to be established so that components can communicate with each other and inter-operate.24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Unfortunately, several competing component standards were established:24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Sun’s Enterprise Java Beans24</div>
# {'Enterprise Java Beans', 'Sun'}
# None
#
# <div></tab>&emsp;&#8226;Microsoft’s COM and .NET24</div>
# {'COM', 'Microsoft'}
# None
#
# <div></tab>&emsp;&#8226;CORBA’s CCM24</div>
# {'CORBA', 'CCM'}
# None
#
# <div></tab>&emsp;&#8226;In practice, these multiple standards have hindered the uptake of CBSE. It is impossible for components developed using different approaches to work together. 24</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Standards need to be established so that components can communicate with each other and inter-operate.24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Unfortunately, several competing component standards were established:24</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Sun’s Enterprise Java Beans24</div>
# {'Enterprise Java Beans', 'Sun'}
# None
#
# <div></tab>&emsp;&#8226;Microsoft’s COM and .NET24</div>
# {'COM', 'Microsoft'}
# None
#
# <div></tab>&emsp;&#8226;CORBA’s CCM24</div>
# {'CORBA', 'CCM'}
# None
#
# <div></tab>&emsp;&#8226;In practice, these multiple standards have hindered the uptake of CBSE. It is impossible for components developed using different approaches to work together. 24</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;An executable service is a type of independent component. It has a ‘provides’ interface but not a ‘requires’ interface.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;From the outset, services have been based around standards so there are no problems in communicating between services offered by different vendors.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;System performance may be slower with services but this approach is replacing CBSE in many systems.45</div>
# {'System', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Covered in Chapter 1845</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;An executable service is a type of independent component. It has a ‘provides’ interface but not a ‘requires’ interface.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;From the outset, services have been based around standards so there are no problems in communicating between services offered by different vendors.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;System performance may be slower with services but this approach is replacing CBSE in many systems.45</div>
# {'System', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Covered in Chapter 1845</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;An executable service is a type of independent component. It has a ‘provides’ interface but not a ‘requires’ interface.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;From the outset, services have been based around standards so there are no problems in communicating between services offered by different vendors.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;System performance may be slower with services but this approach is replacing CBSE in many systems.45</div>
# {'System', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Covered in Chapter 1845</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;An executable service is a type of independent component. It has a ‘provides’ interface but not a ‘requires’ interface.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;From the outset, services have been based around standards so there are no problems in communicating between services offered by different vendors.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;System performance may be slower with services but this approach is replacing CBSE in many systems.45</div>
# {'System', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Covered in Chapter 1845</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;An executable service is a type of independent component. It has a ‘provides’ interface but not a ‘requires’ interface.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;From the outset, services have been based around standards so there are no problems in communicating between services offered by different vendors.45</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;System performance may be slower with services but this approach is replacing CBSE in many systems.45</div>
# {'System', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Covered in Chapter 1845</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components provide a service without regard to where the component is executing or its programming language27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component is an independent executable entity that can be made up of one or more executable objects;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is published and all interactions are through the published interface;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components provide a service without regard to where the component is executing or its programming language27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component is an independent executable entity that can be made up of one or more executable objects;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is published and all interactions are through the published interface;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components provide a service without regard to where the component is executing or its programming language27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component is an independent executable entity that can be made up of one or more executable objects;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is published and all interactions are through the published interface;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components provide a service without regard to where the component is executing or its programming language27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component is an independent executable entity that can be made up of one or more executable objects;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is published and all interactions are through the published interface;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components provide a service without regard to where the component is executing or its programming language27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component is an independent executable entity that can be made up of one or more executable objects;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is published and all interactions are through the published interface;27</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Councill and Heinmann:17</div>
# {'Councill', 'Heinmann'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a software element that conforms to a component model and can be independently deployed and composed without modification according to a composition standard.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Szyperski:17</div>
# {'Szyperski'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a unit of composition with contractually specified interfaces and explicit context dependencies only. A software component can be deployed independently and is subject to composition by third-parties.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Councill and Heinmann:17</div>
# {'Councill', 'Heinmann'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a software element that conforms to a component model and can be independently deployed and composed without modification according to a composition standard.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Szyperski:17</div>
# {'Szyperski'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a unit of composition with contractually specified interfaces and explicit context dependencies only. A software component can be deployed independently and is subject to composition by third-parties.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Councill and Heinmann:17</div>
# {'Councill', 'Heinmann'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a software element that conforms to a component model and can be independently deployed and composed without modification according to a composition standard.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Szyperski:17</div>
# {'Szyperski'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a unit of composition with contractually specified interfaces and explicit context dependencies only. A software component can be deployed independently and is subject to composition by third-parties.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Councill and Heinmann:17</div>
# {'Councill', 'Heinmann'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a software element that conforms to a component model and can be independently deployed and composed without modification according to a composition standard.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Szyperski:17</div>
# {'Szyperski'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a unit of composition with contractually specified interfaces and explicit context dependencies only. A software component can be deployed independently and is subject to composition by third-parties.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Councill and Heinmann:17</div>
# {'Councill', 'Heinmann'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a software element that conforms to a component model and can be independently deployed and composed without modification according to a composition standard.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Szyperski:17</div>
# {'Szyperski'}
# None
#
# <div></tab>&emsp;&#8226;A software component is a unit of composition with contractually specified interfaces and explicit context dependencies only. A software component can be deployed independently and is subject to composition by third-parties.17</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Composable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;For a component to be composable, all external interactions must take place through publicly defined interfaces. In addition, it must provide external access to information about itself, such as its methods and attributes.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;To be deployable, a component has to be self-contained. It must be able to operate as a stand-alone entity on a component platform that provides an implementation of the component model. This usually means that the component is binary and does not have to be compiled before it is deployed. If a component is implemented as a service, it does not have to be deployed by a user of a component. Rather, it is deployed by the service provider. 15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Documented15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components have to be fully documented so that potential users can decide whether or not the components meet their needs. The syntax and, ideally, the semantics of all component interfaces should be specified.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component should be independent—it should be possible to compose and deploy it without having to use other specific components. In situations where the component needs externally provided services, these should be explicitly set out in a ‘requires’ interface specification.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Standardized15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standardization means that a component used in a CBSE process has to conform to a standard component model. This model may define component interfaces, component metadata, documentation, composition, and deployment.15</div>
# {'Component', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Composable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;For a component to be composable, all external interactions must take place through publicly defined interfaces. In addition, it must provide external access to information about itself, such as its methods and attributes.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;To be deployable, a component has to be self-contained. It must be able to operate as a stand-alone entity on a component platform that provides an implementation of the component model. This usually means that the component is binary and does not have to be compiled before it is deployed. If a component is implemented as a service, it does not have to be deployed by a user of a component. Rather, it is deployed by the service provider. 15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Documented15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components have to be fully documented so that potential users can decide whether or not the components meet their needs. The syntax and, ideally, the semantics of all component interfaces should be specified.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component should be independent—it should be possible to compose and deploy it without having to use other specific components. In situations where the component needs externally provided services, these should be explicitly set out in a ‘requires’ interface specification.15</div>
# set()
# None
# <div></tab>&emsp;&#8226;Standardized15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standardization means that a component used in a CBSE process has to conform to a standard component model. This model may define component interfaces, component metadata, documentation, composition, and deployment.15</div>
# {'Component', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Composable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;For a component to be composable, all external interactions must take place through publicly defined interfaces. In addition, it must provide external access to information about itself, such as its methods and attributes.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;To be deployable, a component has to be self-contained. It must be able to operate as a stand-alone entity on a component platform that provides an implementation of the component model. This usually means that the component is binary and does not have to be compiled before it is deployed. If a component is implemented as a service, it does not have to be deployed by a user of a component. Rather, it is deployed by the service provider. 15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Documented15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components have to be fully documented so that potential users can decide whether or not the components meet their needs. The syntax and, ideally, the semantics of all component interfaces should be specified.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component should be independent—it should be possible to compose and deploy it without having to use other specific components. In situations where the component needs externally provided services, these should be explicitly set out in a ‘requires’ interface specification.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Standardized15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standardization means that a component used in a CBSE process has to conform to a standard component model. This model may define component interfaces, component metadata, documentation, composition, and deployment.15</div>
# {'Component', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Composable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;For a component to be composable, all external interactions must take place through publicly defined interfaces. In addition, it must provide external access to information about itself, such as its methods and attributes.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;To be deployable, a component has to be self-contained. It must be able to operate as a stand-alone entity on a component platform that provides an implementation of the component model. This usually means that the component is binary and does not have to be compiled before it is deployed. If a component is implemented as a service, it does not have to be deployed by a user of a component. Rather, it is deployed by the service provider. 15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Documented15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components have to be fully documented so that potential users can decide whether or not the components meet their needs. The syntax and, ideally, the semantics of all component interfaces should be specified.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component should be independent—it should be possible to compose and deploy it without having to use other specific components. In situations where the component needs externally provided services, these should be explicitly set out in a ‘requires’ interface specification.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Standardized15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standardization means that a component used in a CBSE process has to conform to a standard component model. This model may define component interfaces, component metadata, documentation, composition, and deployment.15</div>
# {'Component', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Composable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;For a component to be composable, all external interactions must take place through publicly defined interfaces. In addition, it must provide external access to information about itself, such as its methods and attributes.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployable15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;To be deployable, a component has to be self-contained. It must be able to operate as a stand-alone entity on a component platform that provides an implementation of the component model. This usually means that the component is binary and does not have to be compiled before it is deployed. If a component is implemented as a service, it does not have to be deployed by a user of a component. Rather, it is deployed by the service provider. 15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Documented15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components have to be fully documented so that potential users can decide whether or not the components meet their needs. The syntax and, ideally, the semantics of all component interfaces should be specified.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Independent15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component should be independent—it should be possible to compose and deploy it without having to use other specific components. In situations where the component needs externally provided services, these should be explicitly set out in a ‘requires’ interface specification.15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Standardized15</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component standardization means that a component used in a CBSE process has to conform to a standard component model. This model may define component interfaces, component metadata, documentation, composition, and deployment.15</div>
# {'Component', 'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;The component is an independent, executable entity. It does not have to be compiled before it is used with other components.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The services offered by a component are made available through an interface and all component interactions take place through that interface.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is expressed in terms of parameterized operations and its internal state is never exposed. 14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component is an independent, executable entity. It does not have to be compiled before it is used with other components.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The services offered by a component are made available through an interface and all component interactions take place through that interface.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is expressed in terms of parameterized operations and its internal state is never exposed. 14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component is an independent, executable entity. It does not have to be compiled before it is used with other components.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The services offered by a component are made available through an interface and all component interactions take place through that interface.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is expressed in terms of parameterized operations and its internal state is never exposed. 14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component is an independent, executable entity. It does not have to be compiled before it is used with other components.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The services offered by a component are made available through an interface and all component interactions take place through that interface.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is expressed in terms of parameterized operations and its internal state is never exposed. 14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component is an independent, executable entity. It does not have to be compiled before it is used with other components.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The services offered by a component are made available through an interface and all component interactions take place through that interface.14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component interface is expressed in terms of parameterized operations and its internal state is never exposed. 14</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Provides interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that are provided by the component to other components.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This interface, essentially, is the component API. It defines the methods that can be called by a user of the component. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Requires interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that specifies what services must be made available for the component to execute as specified.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This does not compromise the independence or deployability of a component because the ‘requires’ interface does not define how these services should be provided. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Provides interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that are provided by the component to other components.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This interface, essentially, is the component API. It defines the methods that can be called by a user of the component. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Requires interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that specifies what services must be made available for the component to execute as specified.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This does not compromise the independence or deployability of a component because the ‘requires’ interface does not define how these services should be provided. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Provides interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that are provided by the component to other components.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This interface, essentially, is the component API. It defines the methods that can be called by a user of the component. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Requires interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that specifies what services must be made available for the component to execute as specified.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This does not compromise the independence or deployability of a component because the ‘requires’ interface does not define how these services should be provided. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Provides interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that are provided by the component to other components.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This interface, essentially, is the component API. It defines the methods that can be called by a user of the component. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Requires interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that specifies what services must be made available for the component to execute as specified.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This does not compromise the independence or deployability of a component because the ‘requires’ interface does not define how these services should be provided. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Provides interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that are provided by the component to other components.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This interface, essentially, is the component API. It defines the methods that can be called by a user of the component. 20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Requires interface20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Defines the services that specifies what services must be made available for the component to execute as specified.20</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;This does not compromise the independence or deployability of a component because the ‘requires’ interface does not define how these services should be provided. 20</div>
# set()
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;Note UML notation. Ball and sockets can fit together.21</div>
# {'Note'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;Note UML notation. Ball and sockets can fit together.21</div>
# {'Note'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;Note UML notation. Ball and sockets can fit together.21</div>
# {'Note'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;Note UML notation. Ball and sockets can fit together.21</div>
# {'Note'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;Note UML notation. Ball and sockets can fit together.21</div>
# {'Note'}
# None
#
# <div></tab>&emsp;&#8226;Components are accessed using remote procedure calls (RPCs).13</div>
# {'RPCs'}
# None
#
# <div></tab>&emsp;&#8226;Each component has a unique identifier (usually a URL) and can be referenced from any networked computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Therefore it can be called in a similar way as a procedure or method running on a local computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are accessed using remote procedure calls (RPCs).13</div>
# {'RPCs'}
# None
#
# <div></tab>&emsp;&#8226;Each component has a unique identifier (usually a URL) and can be referenced from any networked computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Therefore it can be called in a similar way as a procedure or method running on a local computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are accessed using remote procedure calls (RPCs).13</div>
# {'RPCs'}
# None
#
# <div></tab>&emsp;&#8226;Each component has a unique identifier (usually a URL) and can be referenced from any networked computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Therefore it can be called in a similar way as a procedure or method running on a local computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are accessed using remote procedure calls (RPCs).13</div>
# {'RPCs'}
# None
#
# <div></tab>&emsp;&#8226;Each component has a unique identifier (usually a URL) and can be referenced from any networked computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Therefore it can be called in a similar way as a procedure or method running on a local computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are accessed using remote procedure calls (RPCs).13</div>
# {'RPCs'}
# None
#
# <div></tab>&emsp;&#8226;Each component has a unique identifier (usually a URL) and can be referenced from any networked computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Therefore it can be called in a similar way as a procedure or method running on a local computer.13</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model is a definition of standards for component implementation, documentation and deployment.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Examples of component models23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;EJB model (Enterprise Java Beans)23</div>
# {'EJB', 'Enterprise Java Beans'}
# None
#
# <div></tab>&emsp;&#8226;COM+ model (.NET model)23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Corba Component Model23</div>
# {'Corba'}
# None
#
# <div></tab>&emsp;&#8226;The component model specifies how interfaces should be defined and the elements that should be included in an interface definition.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model is a definition of standards for component implementation, documentation and deployment.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Examples of component models23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;EJB model (Enterprise Java Beans)23</div>
# {'EJB', 'Enterprise Java Beans'}
# None
#
# <div></tab>&emsp;&#8226;COM+ model (.NET model)23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Corba Component Model23</div>
# {'Corba'}
# None
#
# <div></tab>&emsp;&#8226;The component model specifies how interfaces should be defined and the elements that should be included in an interface definition.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model is a definition of standards for component implementation, documentation and deployment.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Examples of component models23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;EJB model (Enterprise Java Beans)23</div>
# {'EJB', 'Enterprise Java Beans'}
# None
#
# <div></tab>&emsp;&#8226;COM+ model (.NET model)23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Corba Component Model23</div>
# {'Corba'}
# None
#
# <div></tab>&emsp;&#8226;The component model specifies how interfaces should be defined and the elements that should be included in an interface definition.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model is a definition of standards for component implementation, documentation and deployment.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Examples of component models23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;EJB model (Enterprise Java Beans)23</div>
# {'EJB', 'Enterprise Java Beans'}
# None
#
# <div></tab>&emsp;&#8226;COM+ model (.NET model)23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Corba Component Model23</div>
# {'Corba'}
# None
#
# <div></tab>&emsp;&#8226;The component model specifies how interfaces should be defined and the elements that should be included in an interface definition.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model is a definition of standards for component implementation, documentation and deployment.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Examples of component models23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;EJB model (Enterprise Java Beans)23</div>
# {'EJB', 'Enterprise Java Beans'}
# None
#
# <div></tab>&emsp;&#8226;COM+ model (.NET model)23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Corba Component Model23</div>
# {'Corba'}
# None
#
# <div></tab>&emsp;&#8226;The component model specifies how interfaces should be defined and the elements that should be included in an interface definition.23</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Interfaces 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are defined by specifying their interfaces. The component model specifies how the interfaces should be defined and the elements, such as operation names, parameters and exceptions, which should be included in the interface definition. 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Usage 32</div>
# {'Usage'}
# None
#
# <div></tab>&emsp;&#8226;In order for components to be distributed and accessed remotely, they need to have a unique name or handle associated with them. This has to be globally unique.32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployment 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component model includes a specification of how components should be packaged for deployment as independent, executable entities.  32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Interfaces 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are defined by specifying their interfaces. The component model specifies how the interfaces should be defined and the elements, such as operation names, parameters and exceptions, which should be included in the interface definition. 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Usage 32</div>
# {'Usage'}
# None
#
# <div></tab>&emsp;&#8226;In order for components to be distributed and accessed remotely, they need to have a unique name or handle associated with them. This has to be globally unique.32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployment 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component model includes a specification of how components should be packaged for deployment as independent, executable entities.  32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Interfaces 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are defined by specifying their interfaces. The component model specifies how the interfaces should be defined and the elements, such as operation names, parameters and exceptions, which should be included in the interface definition. 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Usage 32</div>
# {'Usage'}
# None
#
# <div></tab>&emsp;&#8226;In order for components to be distributed and accessed remotely, they need to have a unique name or handle associated with them. This has to be globally unique.32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployment 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component model includes a specification of how components should be packaged for deployment as independent, executable entities.  32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Interfaces 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are defined by specifying their interfaces. The component model specifies how the interfaces should be defined and the elements, such as operation names, parameters and exceptions, which should be included in the interface definition. 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Usage 32</div>
# {'Usage'}
# None
#
# <div></tab>&emsp;&#8226;In order for components to be distributed and accessed remotely, they need to have a unique name or handle associated with them. This has to be globally unique.32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployment 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component model includes a specification of how components should be packaged for deployment as independent, executable entities.  32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Interfaces 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components are defined by specifying their interfaces. The component model specifies how the interfaces should be defined and the elements, such as operation names, parameters and exceptions, which should be included in the interface definition. 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Usage 32</div>
# {'Usage'}
# None
#
# <div></tab>&emsp;&#8226;In order for components to be distributed and accessed remotely, they need to have a unique name or handle associated with them. This has to be globally unique.32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Deployment 32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The component model includes a specification of how components should be packaged for deployment as independent, executable entities.  32</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component models are the basis for middleware that provides support for executing components.40</div>
# {'Component'}
# None
#
# <div></tab>&emsp;&#8226;Component model implementations provide:40</div>
# {'Component'}
# None
#
# <div></tab>&emsp;&#8226;Platform services that allow components written according to the model to communicate;40</div>
# {'Platform'}
# None
#
# <div></tab>&emsp;&#8226;Support services that are application-independent services used by different components.40</div>
# {'Support'}
# None
#
# <div></tab>&emsp;&#8226;To use services provided by a model, components are deployed in a container. This is a set of interfaces used to access the service implementations.40</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Component models are the basis for middleware that provides support for executing components.40</div>
# {'Component'}
# None
#
# ...
# {'UML', 'Object Constraint Language', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;It is based around the notion of pre and post condition specification – common to many formal methods.48</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The Object Constraint Language (OCL) has been designed to define constraints that are associated with UML models.48</div>
# {'UML', 'Object Constraint Language', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;It is based around the notion of pre and post condition specification – common to many formal methods.48</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The Object Constraint Language (OCL) has been designed to define constraints that are associated with UML models.48</div>
# {'UML', 'Object Constraint Language', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;It is based around the notion of pre and post condition specification – common to many formal methods.48</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The Object Constraint Language (OCL) has been designed to define constraints that are associated with UML models.48</div>
# {'UML', 'Object Constraint Language', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;It is based around the notion of pre and post condition specification – common to many formal methods.48</div>
# set()
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;-- The context keyword names the component to which the conditions apply
# 47</div>
# set()
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;context addItem 47</div>
# {'addItem'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;-- The context keyword names the component to which the conditions apply
# 47</div>
# set()
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;context addItem 47</div>
# {'addItem'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;-- The context keyword names the component to which the conditions apply
# 47</div>
# set()
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;context addItem 47</div>
# {'addItem'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;-- The context keyword names the component to which the conditions apply
# 47</div>
# set()
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;context addItem 47</div>
# {'addItem'}
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;-- The context keyword names the component to which the conditions apply
# 47</div>
# set()
# None
#
# <div></tab>&emsp;&emsp;&emsp;&#8226;context addItem 47</div>
# {'addItem'}
# None
#
# <div></tab>&emsp;&#8226;As specified, the OCL associated with the Photo Library component states that:43</div>
# {'Photo', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;There must not be a photograph in the library with the same identifier as the photograph to be entered;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The library must exist - assume that creating a library adds a single item to it;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Each new entry increases the size of the library by 1;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you retrieve using the same identifier then you get back the photo that you added;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you look up the catalogue using that identifier, then you get back the catalogue entry that you made.43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;As specified, the OCL associated with the Photo Library component states that:43</div>
# {'Photo', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;There must not be a photograph in the library with the same identifier as the photograph to be entered;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The library must exist - assume that creating a library adds a single item to it;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Each new entry increases the size of the library by 1;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you retrieve using the same identifier then you get back the photo that you added;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you look up the catalogue using that identifier, then you get back the catalogue entry that you made.43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;As specified, the OCL associated with the Photo Library component states that:43</div>
# {'Photo', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;There must not be a photograph in the library with the same identifier as the photograph to be entered;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The library must exist - assume that creating a library adds a single item to it;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Each new entry increases the size of the library by 1;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you retrieve using the same identifier then you get back the photo that you added;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you look up the catalogue using that identifier, then you get back the catalogue entry that you made.43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;As specified, the OCL associated with the Photo Library component states that:43</div>
# {'Photo', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;There must not be a photograph in the library with the same identifier as the photograph to be entered;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The library must exist - assume that creating a library adds a single item to it;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Each new entry increases the size of the library by 1;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you retrieve using the same identifier then you get back the photo that you added;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you look up the catalogue using that identifier, then you get back the catalogue entry that you made.43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;As specified, the OCL associated with the Photo Library component states that:43</div>
# {'Photo', 'OCL'}
# None
#
# <div></tab>&emsp;&#8226;There must not be a photograph in the library with the same identifier as the photograph to be entered;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The library must exist - assume that creating a library adds a single item to it;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Each new entry increases the size of the library by 1;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you retrieve using the same identifier then you get back the photo that you added;43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;If you look up the catalogue using that identifier, then you get back the catalogue entry that you made.43</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing components, you may find conflicts between functional and non-functional requirements, and conflicts between the need for rapid delivery and system evolution.30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;You need to make decisions such as:30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components is effective for delivering the functional requirements?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components allows for future change?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What will be the emergent properties of the composed system?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing components, you may find conflicts between functional and non-functional requirements, and conflicts between the need for rapid delivery and system evolution.30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;You need to make decisions such as:30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components is effective for delivering the functional requirements?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components allows for future change?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What will be the emergent properties of the composed system?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing components, you may find conflicts between functional and non-functional requirements, and conflicts between the need for rapid delivery and system evolution.30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;You need to make decisions such as:30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components is effective for delivering the functional requirements?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components allows for future change?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What will be the emergent properties of the composed system?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing components, you may find conflicts between functional and non-functional requirements, and conflicts between the need for rapid delivery and system evolution.30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;You need to make decisions such as:30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components is effective for delivering the functional requirements?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components allows for future change?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What will be the emergent properties of the composed system?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing components, you may find conflicts between functional and non-functional requirements, and conflicts between the need for rapid delivery and system evolution.30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;You need to make decisions such as:30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components is effective for delivering the functional requirements?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What composition of components allows for future change?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;What will be the emergent properties of the composed system?30</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;CBSE is a reuse-based approach to defining and implementing loosely coupled components into systems.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;A component is a software unit whose functionality and dependencies are completely defined by its interfaces.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components may be implemented as executable elements included in a system or as external services.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model defines a set of standards that component providers and composers should follow.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The key CBSE processes are CBSE for reuse and CBSE with reuse.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;CBSE is a reuse-based approach to defining and implementing loosely coupled components into systems.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;A component is a software unit whose functionality and dependencies are completely defined by its interfaces.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components may be implemented as executable elements included in a system or as external services.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model defines a set of standards that component providers and composers should follow.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The key CBSE processes are CBSE for reuse and CBSE with reuse.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;CBSE is a reuse-based approach to defining and implementing loosely coupled components into systems.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;A component is a software unit whose functionality and dependencies are completely defined by its interfaces.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components may be implemented as executable elements included in a system or as external services.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model defines a set of standards that component providers and composers should follow.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The key CBSE processes are CBSE for reuse and CBSE with reuse.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;CBSE is a reuse-based approach to defining and implementing loosely coupled components into systems.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;A component is a software unit whose functionality and dependencies are completely defined by its interfaces.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components may be implemented as executable elements included in a system or as external services.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model defines a set of standards that component providers and composers should follow.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The key CBSE processes are CBSE for reuse and CBSE with reuse.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;CBSE is a reuse-based approach to defining and implementing loosely coupled components into systems.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;A component is a software unit whose functionality and dependencies are completely defined by its interfaces.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;Components may be implemented as executable elements included in a system or as external services.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;A component model defines a set of standards that component providers and composers should follow.None</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;The key CBSE processes are CBSE for reuse and CBSE with reuse.None</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;During the CBSE process, the processes of requirements engineering and system design are interleaved.37</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition is the process of ‘wiring’ components together to create a system.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing reusable components, you normally have to write adaptors to reconcile different component interfaces.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When choosing compositions, you have to consider required functionality, non-functional requirements and system evolution.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;During the CBSE process, the processes of requirements engineering and system design are interleaved.37</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition is the process of ‘wiring’ components together to create a system.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing reusable components, you normally have to write adaptors to reconcile different component interfaces.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When choosing compositions, you have to consider required functionality, non-functional requirements and system evolution.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;During the CBSE process, the processes of requirements engineering and system design are interleaved.37</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition is the process of ‘wiring’ components together to create a system.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing reusable components, you normally have to write adaptors to reconcile different component interfaces.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When choosing compositions, you have to consider required functionality, non-functional requirements and system evolution.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;During the CBSE process, the processes of requirements engineering and system design are interleaved.37</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition is the process of ‘wiring’ components together to create a system.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing reusable components, you normally have to write adaptors to reconcile different component interfaces.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When choosing compositions, you have to consider required functionality, non-functional requirements and system evolution.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;During the CBSE process, the processes of requirements engineering and system design are interleaved.37</div>
# {'CBSE'}
# None
#
# <div></tab>&emsp;&#8226;Component composition is the process of ‘wiring’ components together to create a system.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When composing reusable components, you normally have to write adaptors to reconcile different component interfaces.37</div>
# set()
# None
#
# <div></tab>&emsp;&#8226;When choosing compositions, you have to consider required functionality, non-functional requirements and system evolution.37</div>
# set()
# None

# %%
entity_names
